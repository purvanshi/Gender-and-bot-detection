# %%
import pandas as pd
import numpy as np
import pickle
import os
import copy

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_fscore_support, classification_report

# %% [markdown]
# ## Read data

# %%
fName = ['id', 'avg_ADJ', 'avg_ADP', 'avg_ADV', 'avg_AUX', 'avg_CCONJ', 'avg_CONJ', 'avg_DET', 'avg_EOL', 'avg_INTJ', 'avg_NOUN', 'avg_NO_TAG', 'avg_NUM', 'avg_PART', 'avg_PRON', 'avg_PROPN', 'avg_PUNCT', 'avg_SCONJ', 'avg_SPACE', 'avg_SYM', 'avg_Tops', 'avg_VERB', 'avg_X', 'avg_act', 'avg_adjectives_for_people', 'avg_animal', 'avg_april_fool', 'avg_art', 'avg_artifact', 'avg_astronomy', 'avg_attribute', 'avg_baseball', 'avg_bathroom', 'avg_beach', 'avg_big', 'avg_biomes', 'avg_birds', 'avg_birthday', 'avg_boat', 'avg_bodies_of_water', 'avg_body', 'avg_buildings', 'avg_camping', 'avg_car', 'avg_carnival', 'avg_carparts', 'avg_castle', 'avg_cats', 'avg_change', 'avg_christmas', 'avg_circus', 'avg_clothes', 'avg_cognition', 'avg_colors', 'avg_communication', 'avg_competition', 'avg_computer', 'avg_constitution', 'avg_consumption', 'avg_contact', 'avg_container', 'avg_cooking', 'avg_cooking_tools', 'avg_country', 'avg_creation', 'avg_dance', 'avg_dentist', 'avg_desserts', 'avg_doctor', 'avg_dogs', 'avg_driving', 'avg_election', 'avg_emotion', 'avg_emotions', 'avg_energy', 'avg_event', 'avg_fall', 'avg_family', 'avg_farm', 'avg_feeling', 'avg_fish', 'avg_flowers', 'avg_food', 'avg_foodweb', 'avg_fruit', 'avg_furniture', 'avg_geography', 'avg_grammar', 'avg_group', 'avg_happiness', 'avg_happy', 'avg_house', 'avg_housing', 'avg_insect', 'avg_jobs', 'avg_kitchen', 'avg_land_forms', 'avg_languages', 'avg_leaders', 'avg_legal', 'avg_location', 'avg_mammal', 'avg_many', 'avg_math', 'avg_maxWordAppearancePerTweet', 'avg_measurement', 'avg_metals', 'avg_military', 'avg_money', 'avg_motion', 'avg_motive', 'avg_music_theory', 'avg_musical_instruments', 'avg_mythical_beasts', 'avg_negative_words', 'avg_new_year', 'avg_noURL', 'avg_nocf', 'avg_noclPerWord', 'avg_noe', 'avg_nos', 'avg_now', 'avg_nowr', 'avg_object', 'avg_ocean', 'avg_office', 'avg_people', 'avg_perception', 'avg_person', 'avg_phenomenon', 'avg_pirate', 'avg_plant', 'avg_plants', 'avg_positive_words', 'avg_possession', 'avg_postal', 'avg_process', 'avg_quantity', 'avg_readabilityScore', 'avg_relation', 'avg_reptiles', 'avg_restaurant', 'avg_roadways', 'avg_rocks', 'avg_rooms', 'avg_school', 'avg_science', 'avg_sciences', 'avg_shape', 'avg_social', 'avg_state', 'avg_stative', 'avg_substance', 'avg_time', 'avg_tree', 'avg_vacation', 'avg_valentine', 'avg_vegetables', 'avg_virtues', 'avg_water', 'avg_weapons', 'avg_weather', 'avg_winter', 'avg_yard', 'maxWordAppearancePerProfile', 'bot', 'gender']
# len(fName)

# %%
# fName = ['id']
# fName.extend(pickle.load(open("C:\\Users\\Vanda\\Documents\\PAN19\\data\\pan19-author-profiling-training-2019-01-28\\en_features\\profile\\feature_names.p", "rb")))
# fName.extend(['bot', 'gender'])
# print("Number of features:", len(fName))

# %%
csv_dir = "../pan19-author-profiling-training-2019-01-28/"
df = pd.read_csv(csv_dir+"features.txt", sep='\t', header=None, names=fName, encoding='utf-8-sig')

# df_train = pd.read_csv(csv_dir+"train_features.txt", sep='\t', header=None, names=fName, encoding='utf-8-sig')
# df_dev = pd.read_csv(csv_dir+"dev_features.txt", sep='\t', header=None, names=fName, encoding='utf-8-sig')
# df_test = pd.read_csv(csv_dir+"test_features.txt", sep='\t', header=None, names=fName, encoding='utf-8-sig')
# df_train.columns = fName

# %%
print(df.shape)
# Out:
# (4120, 167)

# %%
df.head()
# Out:
#                                  id  avg_ADJ  avg_ADP  avg_ADV  avg_AUX  \
# 0  b2d5748083d6fdffec6c2d68d4d4442d     2.49     3.12     0.61      0.0
# 1   2bed15d46872169dc7deaf8d2b43a56     2.74     3.14     0.59      0.0
# 2  25395a7dbd2caa3d828bb3dbd57d8857     2.05     3.02     0.50      0.0
# 3  1c9f161414334b286c4dc70163744390     2.37     2.53     0.54      0.0
# 4  1da1f87b3dc778f28268eec70ce94f19     2.14     2.25     0.33      0.0
#
#    avg_CCONJ  avg_CONJ  avg_DET  avg_EOL  avg_INTJ  ...  avg_vegetables  \
# 0       1.54       0.0     1.76      0.0      0.02  ...            0.00
# 1       1.66       0.0     2.04      0.0      0.03  ...            0.00
# 2       1.21       0.0     1.58      0.0      0.07  ...            0.01
# 3       1.11       0.0     1.60      0.0      0.01  ...            0.01
# 4       1.12       0.0     1.37      0.0      0.08  ...            0.00
#
#    avg_virtues  avg_water  avg_weapons  avg_weather  avg_winter  avg_yard  \
# 0         0.24       0.09         0.01         0.25        0.00      0.08
# 1         0.32       0.05         0.01         0.25        0.01      0.02
# 2         0.11       0.08         0.02         0.18        0.00      0.01
# 3         0.23       0.04         0.02         0.20        0.00      0.00
# 4         0.22       0.07         0.01         0.16        0.01      0.02
#
#    maxWordAppearancePerProfile  bot  gender
# 0                          220  bot     bot
# 1                          245  bot     bot
# 2                          271  bot     bot
# 3                          615  bot     bot
# 4                          331  bot     bot
#
# [5 rows x 167 columns]

# %% [markdown]
# ### Shuffle data

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#                                  id  avg_ADJ  avg_ADP  avg_ADV  avg_AUX  \
# 0  f334e25ccf9a18f1eb2cce4572cb141d     1.37     1.03     1.53      0.0
# 1  77b9837ade957f9516672181bd9d6f2f     1.57     1.63     1.63      0.0
# 2  304c12afb0a7e20f49bf84e054993e98     2.59     3.28     0.52      0.0
# 3  b215b99c8f952c5d3136afe860699078     1.46     1.63     0.98      0.0
# 4  6fef26054b494f97955c9427ce0b8b7a     1.39     1.86     0.86      0.0
#
#    avg_CCONJ  avg_CONJ  avg_DET  avg_EOL  avg_INTJ  ...  avg_vegetables  \
# 0       0.52       0.0     0.84      0.0      0.15  ...             0.0
# 1       0.34       0.0     1.60      0.0      0.26  ...             0.0
# 2       1.03       0.0     1.81      0.0      0.09  ...             0.0
# 3       0.47       0.0     1.38      0.0      0.16  ...             0.0
# 4       0.36       0.0     1.47      0.0      0.12  ...             0.0
#
#    avg_virtues  avg_water  avg_weapons  avg_weather  avg_winter  avg_yard  \
# 0         0.12       0.02         0.00         0.13        0.02      0.00
# 1         0.15       0.09         0.00         0.22        0.01      0.01
# 2         0.21       0.05         0.00         0.27        0.00      0.01
# 3         0.10       0.03         0.02         0.13        0.02      0.00
# 4         0.08       0.04         0.04         0.33        0.02      0.02
#
#    maxWordAppearancePerProfile    bot  gender
# 0                          173  human  female
# 1                          140  human    male
# 2                          178    bot     bot
# 3                          102  human  female
# 4                          132  human  female
#
# [5 rows x 167 columns]

# %% [markdown]
# ### Split data

# %%
def getData(df):
    nCols = df.shape[1]
    nFeatures = nCols-3
    X = df.iloc[:, 1:nFeatures+1]
    y_bot = df.iloc[:, nFeatures+1]
    y_gender = df.iloc[:, nFeatures+2]
    X_train, X_test, y_train_bot, y_test_bot, y_train_gender, y_test_gender = train_test_split(X, y_bot, y_gender, test_size=0.33, random_state=42)
    y_train_bot = y_train_bot.values
    y_test_bot = y_test_bot.values
    y_train_gender = y_train_gender.values
    y_test_gender = y_test_gender.values
    i2n = {ind: name for (ind, name) in enumerate(df.iloc[:, 0].tolist())}
    n2i = {name: ind for (ind, name) in i2n.items()}
    return X_train, X_test, y_train_bot, y_test_bot, y_train_gender, y_test_gender, i2n, n2i

# %%
X_train, X_test, y_train_bot, y_test_bot, y_train_gender, y_test_gender, i2n, n2i = getData(df)
# X_train, y_train_bot, y_train_gender, train_i2n, train_n2i = getData(df_train)
# X_dev, y_dev_bot, y_dev_gender, dev_i2n, dev_n2i = getData(df_dev)
# X_test, y_test_bot, y_test_gender, test_i2n, test_n2i = getData(df_test)
print('Train size: ', X_train.shape, '\nTest size: ', X_test.shape)
# Out:
# Train size:  (2760, 164)
# Test size:  (1360, 164)

# %% [markdown]
# #### Filter features

# %%
def filter_features(features, train, dev, test):
    train_f = train[features]
    dev_f = dev[features]
    test_f = test[features]
    return train_f, dev_f, test_f

# %% [markdown]
# #### Drop features

# %%
def drop_features(features, df):
    df.drop(columns=features)

# %% [markdown]
# ## Standardize data

# %%
def standardize(X_train, X_test):
    cols = X_train.columns
    scaler = StandardScaler(copy=True, with_mean=True, with_std=True)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    X_train = pd.DataFrame(X_train, columns=cols)
    X_test = pd.DataFrame(X_test, columns=cols)
    return X_train, X_test

# %%
X_train, X_test = standardize(X_train, X_test)
# Out:
# /data/home/mehta/multimodal/lib/python3.5/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /data/home/mehta/multimodal/lib/python3.5/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /data/home/mehta/multimodal/lib/python3.5/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """

# %%
X_train.head()
# Out:
#     avg_ADJ   avg_ADP   avg_ADV  avg_AUX  avg_CCONJ  avg_CONJ   avg_DET  \
# 0  1.692714  1.326454 -0.376939      0.0   1.346993       0.0  0.719940
# 1 -0.036748  0.411218  0.797847      0.0  -0.362324       0.0  0.263041
# 2  1.692714  2.039800 -0.798088      0.0   2.866385       0.0  1.709888
# 3 -0.551298 -0.638612  0.221537      0.0  -0.710518       0.0 -0.003483
# 4  0.549268 -0.302128  0.199371      0.0   0.144140       0.0 -0.574607
#
#    avg_EOL  avg_INTJ  avg_NOUN  ...  avg_vacation  avg_valentine  \
# 0      0.0  0.782967  2.338460  ...     -0.052368       0.317320
# 1      0.0  0.116018 -0.479681  ...     -0.416988      -0.692187
# 2      0.0 -0.328615  2.693688  ...     -0.344064      -0.355684
# 3      0.0 -0.254509 -0.508099  ...      0.385176       0.765990
# 4      0.0  0.634756  1.324876  ...      0.458100       0.765990
#
#    avg_vegetables  avg_virtues  avg_water  avg_weapons  avg_weather  \
# 0       -0.334419     0.667365   1.082610     0.540636     0.261734
# 1       -0.334419     0.007924   1.271928     0.329223     0.001133
# 2        0.549678     1.766431   0.136021    -0.093604     0.782937
# 3       -0.334419    -0.981236   0.325339    -0.093604    -0.433203
# 4       16.463419    -0.431702  -0.242615    -0.305018     0.696070
#
#    avg_winter  avg_yard  maxWordAppearancePerProfile
# 0   -0.497237 -0.104902                     1.808143
# 1   -0.287618  0.402154                    -0.370695
# 2   -0.287618 -0.104902                     0.797533
# 3   -0.497237 -0.611958                     0.167061
# 4    0.341238 -0.611958                     0.556470
#
# [5 rows x 164 columns]

# %%
X_test.head()
# Out:
#     avg_ADJ   avg_ADP   avg_ADV  avg_AUX  avg_CCONJ  avg_CONJ   avg_DET  \
# 0 -0.408368 -0.409803  0.288035      0.0  -0.204054       0.0 -0.117708
# 1  0.049011  0.209327 -0.177447      0.0  -0.267362       0.0  0.167854
# 2 -0.165385 -0.207913 -0.288275      0.0  -0.647210       0.0  0.072667
# 3 -0.665643 -1.002015 -0.199612      0.0  -0.932096       0.0 -0.612682
# 4  1.378267  0.949592  2.371617      0.0   0.555643       0.0  1.214914
#
#    avg_EOL  avg_INTJ  avg_NOUN  ...  avg_vacation  avg_valentine  \
# 0      0.0  1.301705 -0.342326  ...      0.239328      -0.467852
# 1      0.0 -0.106298 -0.228653  ...     -0.708684       0.990324
# 2      0.0  0.857073 -0.195499  ...      0.020556       0.205153
# 3      0.0  0.708862 -1.019628  ...     -0.416988       0.205153
# 4      0.0  0.412440  0.500748  ...      1.770732       1.663329
#
#    avg_vegetables  avg_virtues  avg_water  avg_weapons  avg_weather  \
# 0       -0.334419     0.447551   0.514656     0.329223    -0.346336
# 1        0.549678     0.007924   0.514656    -0.305018     0.522336
# 2       -0.334419    -0.431702  -0.053297    -0.305018    -0.520070
# 3       -0.334419    -0.101982  -0.810568     0.117809    -0.606937
# 4        0.549678     0.227738   0.325339     0.117809     0.869804
#
#    avg_winter  avg_yard  maxWordAppearancePerProfile
# 0   -0.287618 -0.104902                    -0.203805
# 1    0.760476  2.430380                    -0.621029
# 2   -0.497237 -0.611958                    -0.593214
# 3   -0.287618 -0.611958                    -0.074002
# 4   -0.497237 -0.104902                     1.057139
#
# [5 rows x 164 columns]

# %% [markdown]
# ## Drop columns containing the same values

# %%
nunique = X_train.apply(pd.Series.nunique)
cols_to_drop = nunique[nunique == 1].index
X_train = X_train.drop(cols_to_drop, axis=1)
# X_dev = X_dev.drop(cols_to_drop, axis=1)
X_test = X_test.drop(cols_to_drop, axis=1)
X_train.shape
# Out:
# (2760, 159)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (2760, 159) (1360, 159)

# %%
X_test.head(10)
# X_train.iloc[0]
# Out:
#     avg_ADJ   avg_ADP   avg_ADV  avg_CCONJ   avg_DET  avg_INTJ  avg_NOUN  \
# 0 -0.408368 -0.409803  0.288035  -0.204054 -0.117708  1.301705 -0.342326
# 1  0.049011  0.209327 -0.177447  -0.267362  0.167854 -0.106298 -0.228653
# 2 -0.165385 -0.207913 -0.288275  -0.647210  0.072667  0.857073 -0.195499
# 3 -0.665643 -1.002015 -0.199612  -0.932096 -0.612682  0.708862 -1.019628
# 4  1.378267  0.949592  2.371617   0.555643  1.214914  0.412440  0.500748
# 5 -0.165385  0.357380 -1.174906  -0.932096  2.204862 -0.847353  0.169202
# 6 -1.837675  0.747701  0.465361  -1.216982 -0.136746 -0.699142 -1.592729
# 7 -1.180194  0.451596 -1.463061  -0.900442  1.919300 -0.773247 -0.114981
# 8 -0.379781 -0.504019 -0.354773  -0.457286 -0.403270 -0.476826 -0.389690
# 9 -1.780503 -1.944170 -1.684719  -1.216982 -2.040491 -0.847353 -1.445901
#
#     avg_NUM  avg_PART  avg_PRON  ...  avg_vacation  avg_valentine  \
# 0 -0.429878 -0.253563  0.609094  ...      0.239328      -0.467852
# 1 -0.390155 -0.915835 -0.524881  ...     -0.708684       0.990324
# 2 -0.310710 -0.679309  0.061006  ...      0.020556       0.205153
# 3 -0.668216  0.503320  0.684692  ...     -0.416988       0.205153
# 4 -0.429878  1.402118  2.253358  ...      1.770732       1.663329
# 5 -0.449740 -0.773919 -0.657178  ...     -0.198216       0.765990
# 6 -0.747662 -1.814633  2.366755  ...     -1.146228      -1.253024
# 7 -0.688077 -1.578107 -1.337563  ...      0.895644      -0.916521
# 8 -0.390155 -0.206257 -0.222488  ...     -0.198216      -0.019182
# 9 -0.747662 -1.814633 -1.432061  ...     -1.146228      -1.253024
#
#    avg_vegetables  avg_virtues  avg_water  avg_weapons  avg_weather  \
# 0       -0.334419     0.447551   0.514656     0.329223    -0.346336
# 1        0.549678     0.007924   0.514656    -0.305018     0.522336
# 2       -0.334419    -0.431702  -0.053297    -0.305018    -0.520070
# 3       -0.334419    -0.101982  -0.810568     0.117809    -0.606937
# 4        0.549678     0.227738   0.325339     0.117809     0.869804
# 5        1.433774    -0.651516   0.514656    -0.093604     0.435469
# 6       -0.334419    -1.310956  -0.999886    -0.305018    -1.736210
# 7       -0.334419    -1.310956   2.029199    -0.305018     2.433413
# 8       -0.334419    -0.211889   0.703974    -0.305018    -0.085734
# 9       -0.334419    -1.310956  -0.999886    -0.305018    -1.736210
#
#    avg_winter  avg_yard  maxWordAppearancePerProfile
# 0   -0.287618 -0.104902                    -0.203805
# 1    0.760476  2.430380                    -0.621029
# 2   -0.497237 -0.611958                    -0.593214
# 3   -0.287618 -0.611958                    -0.074002
# 4   -0.497237 -0.104902                     1.057139
# 5   -0.287618  3.444492                    -0.268706
# 6   -0.497237 -0.611958                     0.528655
# 7   -0.287618  6.486830                    -1.149513
# 8    0.131619  1.416267                    -0.676659
# 9   -0.497237 -0.611958                    -1.307131
#
# [10 rows x 159 columns]

# %% [markdown]
# ## Misclassified data
# outdated

# %%
def get_misclassified(truth, pred, i2n, out_path):
    misclassified_test = np.where(truth != pred)[0]
    misclassified_ids = [(i2n[i], truth[i], pred[i]) for i in misclassified_test]
    out_file = open(out_path, 'w')
    out_file.write('name,truth,pred\n')
    for id_name, truth, pred in misclassified_ids:
        out_file.write(id_name + ',' + truth + ',' + pred + '\n')

# %%
misclassification_dir = '../../data/misclassification/'
if not os.path.exists(misclassification_dir):
    os.makedirs(misclassification_dir)

# %% [markdown]
# ## Classify

# %%
def classify(classifier_bot, classifier_gender):
    classifier_bot.fit(X_train, y_train_bot)
    y_pred_test_bot = classifier_bot.predict(X_test)
    print("Bot classification")
    print(classification_report(y_test_bot, y_pred_test_bot))

    # preparing for gender classification
    y_pred_train_bot = classifier_bot.predict(X_train)
    human_train_indices = [ind for ind, label in enumerate(y_pred_train_bot) if label=='human']
    human_test_indices = [ind for ind, label in enumerate(y_pred_test_bot) if label=='human']
    X_train_human = X_train.iloc[human_train_indices, :]
    y_train_human_gender = y_train_gender[human_train_indices]
    X_test_human = X_test.iloc[human_test_indices, :]
    y_test_human_gender = y_test_gender[human_test_indices]

    # Gender
    classifier_gender.fit(X_train_human, y_train_human_gender)
    y_pred_test_gender = classifier_gender.predict(X_test_human)
    y_pred_test_gender_all  = y_pred_test_bot
    y_pred_test_gender_all[human_test_indices] = y_pred_test_gender
    print("Gender classification")
    print(classification_report(y_test_human_gender, y_pred_test_gender))
    print("Genfer classification including bots")
    print(classification_report(y_test_gender, y_pred_test_gender_all))

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf1 = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0, class_weight='balanced')
rf2= RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0, class_weight='balanced')
classify(rf1, rf2)
# Out:
# Bot classification
#               precision    recall  f1-score   support
#
#          bot       0.98      0.95      0.96       663
#        human       0.96      0.98      0.97       697
#
#    micro avg       0.97      0.97      0.97      1360
#    macro avg       0.97      0.97      0.97      1360
# weighted avg       0.97      0.97      0.97      1360
#
# Gender classification
#               precision    recall  f1-score   support
#
#          bot       1.00      0.03      0.06        32
#       female       0.83      0.84      0.83       354
#         male       0.81      0.87      0.84       328
#
#    micro avg       0.82      0.82      0.82       714
#    macro avg       0.88      0.58      0.58       714
# weighted avg       0.83      0.82      0.80       714
#
# Genfer classification including bots
#               precision    recall  f1-score   support
#
#          bot       0.98      0.95      0.96       663
#       female       0.83      0.83      0.83       357
#         male       0.81      0.84      0.82       340
#
#    micro avg       0.89      0.89      0.89      1360
#    macro avg       0.87      0.88      0.87      1360
# weighted avg       0.90      0.89      0.89      1360

# %% [markdown]
# ## Ada Boost Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
ada1 = AdaBoostClassifier(DecisionTreeClassifier(max_depth=6), 
                         algorithm="SAMME",
                         n_estimators=500,
                         random_state=0)
ada2 = AdaBoostClassifier(DecisionTreeClassifier(max_depth=6), 
                         algorithm="SAMME",
                         n_estimators=500,
                         random_state=0)
classify(ada1, ada2)
# Out:
# Bot classification
#              precision    recall  f1-score   support
#
#         bot       1.00      0.98      0.99       647
#       human       0.98      1.00      0.99       713
#
# avg / total       0.99      0.99      0.99      1360
#
# Gender classification
#              precision    recall  f1-score   support
#
#         bot       0.00      0.00      0.00        12
#      female       0.88      0.92      0.90       363
#        male       0.90      0.89      0.89       348
#
# avg / total       0.87      0.89      0.88       723
#
# Genfer classification including bots
#              precision    recall  f1-score   support
#
#         bot       1.00      0.98      0.99       647
#      female       0.88      0.92      0.90       363
#        male       0.90      0.88      0.89       350
#
# avg / total       0.94      0.94      0.94      1360
# C:\Users\Vanda\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
bagging1 = BaggingClassifier(KNeighborsClassifier(n_neighbors=3), 
                            max_samples=0.7, 
                            max_features=0.7, 
                            random_state=0)
classify(bagging1, bagging1)
# Out:
# Bot classification
#              precision    recall  f1-score   support
#
#         bot       0.99      0.94      0.97       647
#       human       0.95      0.99      0.97       713
#
# avg / total       0.97      0.97      0.97      1360
#
# Gender classification
#              precision    recall  f1-score   support
#
#         bot       1.00      0.05      0.10        39
#      female       0.84      0.85      0.84       363
#        male       0.80      0.87      0.83       346
#
# avg / total       0.83      0.82      0.80       748
#
# Genfer classification including bots
#              precision    recall  f1-score   support
#
#         bot       0.99      0.94      0.97       647
#      female       0.84      0.85      0.84       363
#        male       0.80      0.86      0.83       350
#
# avg / total       0.90      0.90      0.90      1360

# %% [markdown]
# ## Gradient Tree Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                 max_depth=5, random_state=0)
classify(gbc, gbc)
# Out:
# Bot classification
#              precision    recall  f1-score   support
#
#         bot       0.98      0.97      0.98       647
#       human       0.97      0.98      0.98       713
#
# avg / total       0.98      0.98      0.98      1360
#
# Gender classification
#              precision    recall  f1-score   support
#
#         bot       0.00      0.00      0.00        19
#      female       0.82      0.85      0.84       357
#        male       0.83      0.84      0.84       345
#
# avg / total       0.80      0.83      0.82       721
#
# Genfer classification including bots
#              precision    recall  f1-score   support
#
#         bot       0.98      0.97      0.98       647
#      female       0.82      0.84      0.83       363
#        male       0.83      0.83      0.83       350
#
# avg / total       0.90      0.90      0.90      1360
# C:\Users\Vanda\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Results with sepecifically selected features
# outdated

# %% [markdown]
# ### Select features

# %%
# POS features
all_pos_tags = ["NO_TAG", "ADJ", "ADP", "ADV","AUX", "CONJ","CCONJ","DET",
                      "INTJ","NOUN","NUM","PART","PRON","PROPN","PUNCT","SCONJ","SYM",
                      "VERB","X","EOL","SPACE"]
pos_features = ["avg_"+postag for postag in all_pos_tags]
# topic features
topic_names = ['Tops', 'act', 'adjectives_for_people', 'animal', 'april_fool', 'art', 'artifact', 'astronomy', 'attribute', 'baseball', 'bathroom', 'beach', 'big', 'biomes', 'birds', 'birthday', 'boat', 'bodies_of_water', 'body', 'buildings', 'camping', 'car', 'carnival', 'carparts', 'castle', 'cats', 'change', 'christmas', 'circus', 'clothes', 'cognition', 'colors', 'communication', 'competition', 'computer', 'constitution', 'consumption', 'contact', 'container', 'cooking', 'cooking_tools', 'country', 'creation', 'dance', 'dentist', 'desserts', 'doctor', 'dogs', 'driving', 'election', 'emotion', 'emotions', 'energy', 'event', 'fall', 'family', 'farm', 'feeling', 'fish', 'flowers', 'food', 'foodweb', 'fruit', 'furniture', 'geography', 'grammar', 'group', 'happiness', 'happy', 'house', 'housing', 'insect', 'jobs', 'kitchen', 'land_forms', 'languages', 'leaders', 'legal', 'location', 'mammal', 'many', 'math', 'measurement', 'metals', 'military', 'money', 'motion', 'motive', 'music_theory', 'musical_instruments', 'mythical_beasts', 'negative_words', 'new_year', 'object', 'ocean', 'office', 'people', 'perception', 'person', 'phenomenon', 'pirate', 'plant', 'plants', 'positive_words', 'possession', 'postal', 'process', 'quantity', 'relation', 'reptiles', 'restaurant', 'roadways', 'rocks', 'rooms', 'school', 'science', 'sciences', 'shape', 'social', 'state', 'stative', 'substance', 'time', 'tree', 'vacation', 'valentine', 'vegetables', 'virtues', 'water', 'weapons', 'weather', 'winter', 'yard']
topic_features = ["avg_"+topic for topic in topic_names]
# stylistic features
stylstic_names = ['nos', 'now', 'noclPerWord', 'noe', 'nocf', 'nowr', 'maxWordAppearancePerTweet']
stylstic_features = ["avg_"+n for n in stylstic_names]
stylstic_features.append('maxWordAppearancePerProfile')
# URL features
url_names = ['noURL']
url_features = ["avg_"+n for n in url_names]
# readability features
readability_names = ['readabilityScore']
readability_features = ["avg_"+n for n in readability_names]
# POS + topic
pos_topic_features = []
pos_topic_features.extend(pos_features)
pos_topic_features.extend(topic_features)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
# use AdaBoostClassifier
def feature_pred_ADA(features):
    train_f, dev_f, test_f = filter_features(features, X_train, X_dev, X_test)
    ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5), 
                         algorithm="SAMME",
                         n_estimators=500,
                         random_state=0)
    ada.fit(train_f, y_train_gender)
    y_pred_test = ada.predict(test_f)
    print("Gender classification")
    print(classification_report(y_test_gender, y_pred_test))
    ada.fit(train_f, y_train_bot)
    y_pred_test = ada.predict(test_f)
    print("Bot classification")
    print(classification_report(y_test_bot, y_pred_test))

# %% [markdown]
# ### Stylistic features

# %%
feature_pred_ADA(stylstic_features)

# %% [markdown]
# ### POS tags

# %%
feature_pred_ADA(pos_features)

# %% [markdown]
# ### Topics

# %%
feature_pred_ADA(topic_features)

# %% [markdown]
# ### POS + topic

# %%
feature_pred_ADA(pos_topic_features)

# %% [markdown]
# ### Readability

# %%
feature_pred_ADA(readability_features)

# %% [markdown]
# ### HTML

# %%
feature_pred_ADA(url_features)
